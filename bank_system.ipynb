# %%
balance={'balance':0.00,'deposit':0.00}

# %%
account_number=2134567843

# %%
pin={'t_pin':4356,'m_pin':2022}

# %%
information=()

# %%
def creating_account():
    name=input("type your name:")
    national_ID_NO=input("enter your id number:")
    source=input("how do you earn your money")
    properties=input("enter the properties you own")
    location=input("indicate your address")
    amount=input("estimate the amount you are going to be depositing monthly:")
    card_type=input("indicate card 'classic,Gold or platinum':")
    addition=input("any information you want to add:")
    information={'name':name,'national_ID':national_ID_NO,'source of money':source,'properties you own':properties,'location':location,'amount monthly':amount,'card type':card_type,'addition information':addition}


    print(f"your account has been created successfully and your account number is {account_number} and your pin is {pin} please do not share your pin with anyone")

# %%
def transifer_money():
    print("1.own account")
    print("2. to national bank account")
    print("3.to other bank")
    print("4.to mobile wallet")
    option=int(input("enter your choice:"))
    if option==1:
        account_source=input("enter the source account:")
        account=input("enter the receivers account")
        amount=float(input("amount:"))
        description=input("add a comment:")
        print(f'you have successfully transfelled mkw {amount} from {account_source} to {account}')
    elif option==2:
        print("1.other national bank account")
        print('2.to NBM once off')
        choice=int(input("enter the choice:"))
        if choice==1:
            rec_account=int(input("enter account no:"))
            rec_name=input("enter name of the receiver")
            rec_phone=input("enter phnone# of the receiver:")
            amount=float(input("amount:"))
            print(f"you have successfully deposited {amount} mkw to {rec_account} ")
        elif choice==2:
            source=input("enter the source e.g salary")
            amount=float(input("amount:"))
            account=int(input("account number:"))
            description=input("add a comment:")
            print("money has been transfelled successfully")
        else:
            print("invalid option")
    elif option==3:
        print("1.to other bank")
        print("2.to other bank account")
        choice=int(input("choose :"))
        if choice==1:
            recipient=input("account of the recipient")
            amount=float(input("amount:"))
            description=input("add a comment:")
            print(f'you have sent mkw{amount}  to {recipient} successfully')
        elif choice==2:
            bank=input("name of the bank:")
            account=input("your account NO.:")
            rec_account=input("recipient account:")
            name=input("recipient name:")
            phone=input("recipient phone no.:")
            amount=float(input("amount:"))
            description=input("add a comment:")
            print("money sent successfully!!")
        else:
            print("invalid choice!")
    elif option==4:
        print("1.MO 626 wallet")
        print("2.airtel money")
        print("3.TNM Mpamba")
        choice=int(input("enter your choice:"))
        if choice==1:
            source=input("your account NO.:")
            amount=float(input("amount:"))
            phone=input("enter the phone of the recipient:")
            description=input("add a comment")
            print("money sent successfuly")
        elif choice==2 or choice==3:
            source=input("your account NO.")
            amount=float(input("amount:"))
            phone=input("receiver phone NO.:")
            print("money sent successfuly")
        else:
            print("INVALID CHOICE!!")
    else:
        print("INVALID OPTION!!!!")

# %%
def my_account():
    print("1.balance enquiry")
    print("2.mini statement")
    print("3.interium statement")
    choice=int(input("enter your choice:"))
    if choice==1:
        print(f' your balance is mkw {balance}')
    elif choice==2:
        print(f"the min statement is mkw {balance['deposit']} as deposited and now the balance is {balance['balance']} mkw")
    elif choice==3:
        print("the interium statement will be sent to your g-mail")
    else:
        print("INVALID OPTION!!")

# %%
def withdraw():
    print("1.cadless withdraw")
    print("2.agent direct cash withdraw")
    option=int(input("enter your option:"))
    if option==1:
        print("1.generate for yourself")
        print("2.generate for others")
        print("3.view tockens")
        choice=int(input("choose your option:"))
        if choice==1:
            account=input("your account:")
            card=input("indicate ATM or Agent:")
            amount=float(input("Amount:"))
            print(f"you have withdrown mkw {amount} in account {account} successfully")
            balance['balance']-=amount
        elif choice==2:
            source=input("indicate the source e.g savings")
            card=input("indicate ATM or agent:")
            amount=float(input("AMount:"))
            print("money withdrown successfully!")
        elif choice==3:
            print("still loarding....")
            print("try again another time")
        else:
            print("INVALID OPTION!!")
    elif option==2:
        source=input("your source account:")
        code=input("the agent code:")
        amount=float(input("AMOUNT:"))
        balance['balance']-=amount
        print(f"you have  withdrown {amount} successfully")
    else:
        print("INVALID OPTION!!")

# %%
def deposite():
    source=input("source account:")
    amount=float(input("AMOUNT:"))
    balance['balance']+=amount
    balance['deposit']+=amount
    if amount>0:
        print(f'you have deposited mkw {amount} successfuly')
    elif amount<=0:
        print(f'you cant deposit negative money!!!')

# %%
def my_profile():
    print("=== change pin===")
    t_pin=input("new t_pin:")
    m_pin=input("new m_pin")
    pin['t_pin']=t_pin
    pin['m_pin']=m_pin
    
    print("pins changed successfully")

# %%
def top_up():
    print("1.Airtel ")
    print("2.TNM")
    choice=int(input("choose:"))
    if choice==1 or choice==2:
        source=input("enter savings or any source:")
        phone=input("phone number:")
        amount=float(input("AMOUNT:"))
        balance['balance']-=amount
        print(f'you have purchased airtime of {amount} mkw to {phone} successfully')
    else:
        print("INVALID OPTION!!")

# %%
def payment():
    print("1. tax payment")
    print("2.DSTV ")
    print('3. tertiary education')
    print("4.MASM payment")
    choice=int(input("choose:"))
    if choice==1:
        source=input("source aCCOUNT:")
        prn=input("put the PRN:")
        amount=float(input("AMOUNT:"))
        balance['balance']-=amount
        print(f'you have paid mkw {amount}  tax successfully')
    elif choice==2:
        number=input("recipient's number:")
        smartcard=input("enter smartcard number:")
        print("submitted")
    elif choice==3:
        source=input("enter source account:")
        institution=input("enter institution:")
        studentID=input("enter studentID:")
        amount=float(input("AMOUNT:"))
        balance['balance']-=amount
        print(f' you have paid  mkw {amount} to {institution} for {studentID} ')
    elif choice==4:
        MASM=input("enter  your scheme number:")
        print("submitted")
    else:
        print("INVALLID OPTION !!")

# %%
def loan():
    print("1.loarn application")
    print("2.loan payment")
    print("3. loan calculations")
    choice=int(input("choose:"))
    if choice==1:
        loan_type=input("enter loarn type:")
        amount=float(input("AMOUNT:"))
        balance['balance']+=amount
        print("===accept tems and conditions===")
        print(f'your loan of {amount} mkw has been granted!!!')
    elif choice==2:
        amount=float(input("AMOUNT:"))
        balance['balance']-=amount
        print(f' you have paid your loan')
    elif choice==3:
        amount=float(input("AMOUNT:"))
        months=int(input("enter months taken:"))
        si=amount*0.3*months
        total=si+amount
        print(f'you will be expected to pay mkw{total} after bollowing mkw{amount}')
    else:
        print("INVALID OPTION!!")

# %%
def bank_system():
    while True:
        print("==welcome to our bank===")
        print("1.create an account")
        print("2.deposite money")
        print("3.loan")
        print("4.withdraw")
        print("5.my account")
        print("6.money transfer")
        print("7.my profile")
        print("8.payment")
        print("9.top up")
        print("10.exit")
        choice=int(input("what do you want to do:"))
        if choice==1:
            creating_account()
        elif choice==2:
             deposite()
        elif choice==3:
             loan()
        elif choice==4:
             withdraw()
        elif choice==5:
             my_account()
        elif choice==6:
            transifer_money()
        elif choice==7:
             my_profile()
        elif choice==8:
             payment()
        elif choice==9:
            top_up()
        elif choice==10:
            print("exiting.....")
            break
        else:
            print("INVALID OPTION!!!")

# %%
bank_system()
# Out:
# ==welcome to our bank===
# 1.create an account
# 2.deposite money
# 3.loan
# 4.withdraw
# 5.my account
# 6.money transfer
# 7.my profile
# 8.payment
# 9.top up
# 10.exit
# what do you want to do: 10
# exiting.....
